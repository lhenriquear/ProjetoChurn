# %%
# Importar as bibliotecas necessárias
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier, plot_tree
from xgboost import XGBClassifier
from sklearn.metrics import plot_confusion_matrix, confusion_matrix, f1_score, accuracy_score, recall_score, precision_score, plot_roc_curve
from sklearn.ensemble import VotingClassifier
from imblearn.over_sampling import ADASYN
from collections import Counter
pd.set_option('display.max_columns', None)
import warnings
warnings.filterwarnings("ignore")

# %%
# Abrir as tabelas .csv como dataframes de trabalho
gg_train = pd.read_csv('../CSVs/games_train.csv')
gg_test = pd.read_csv('../CSVs/games_test.csv')

# %%
gg_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14084 entries, 0 to 14083
# Data columns (total 40 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   user_id            14084 non-null  int64
#  1   email              14084 non-null  int64
#  2   name               14084 non-null  int64
#  3   nickname           14084 non-null  int64
#  4   avatar             14084 non-null  int64
#  5   profile_pic_id     14084 non-null  int64
#  6   city               14084 non-null  int64
#  7   ip_country_code    14084 non-null  int64
#  8   lat                9980 non-null   float64
#  9   lng                9980 non-null   float64
#  10  fbid               14084 non-null  int64
#  11  quickblox_id       14084 non-null  int64
#  12  steam_id           14084 non-null  int64
#  13  psn_id             14084 non-null  int64
#  14  xboxlive_id        14084 non-null  int64
#  15  nintendo_id        14084 non-null  int64
#  16  gamecenter_id      14084 non-null  int64
#  17  googleplay_id      14084 non-null  int64
#  18  battlenet_id       14084 non-null  int64
#  19  uplay_id           14084 non-null  int64
#  20  origin_id          14084 non-null  int64
#  21  youtube_id         14084 non-null  int64
#  22  twitch_id          14084 non-null  int64
#  23  phone_number       14084 non-null  int64
#  24  creation_datetime  14084 non-null  object
#  25  last_login         14084 non-null  object
#  26  last_interaction   14084 non-null  object
#  27  qtde_games         14084 non-null  float64
#  28  qtde_grupos        14084 non-null  float64
#  29  qtde_contatos      14084 non-null  float64
#  30  qtde_eventos       14084 non-null  float64
#  31  qtde_mensagens     14084 non-null  float64
#  32  qtde_plataformas   14084 non-null  float64
#  33  qtde_acessos       14084 non-null  float64
#  34  inatividade        14084 non-null  object
#  35  inatividade_days   14084 non-null  int64
#  36  churn              14084 non-null  bool
#  37  tempo_uso          14084 non-null  object
#  38  tempo_uso_days     14084 non-null  int64
#  39  pouco_uso          14084 non-null  bool
# dtypes: bool(2), float64(9), int64(24), object(5)
# memory usage: 4.1+ MB

# %%
gg_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6036 entries, 0 to 6035
# Data columns (total 39 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   user_id            6036 non-null   int64
#  1   email              6036 non-null   int64
#  2   name               6036 non-null   int64
#  3   nickname           6036 non-null   int64
#  4   avatar             6036 non-null   int64
#  5   profile_pic_id     6036 non-null   int64
#  6   city               6036 non-null   int64
#  7   ip_country_code    6036 non-null   int64
#  8   lat                4222 non-null   float64
#  9   lng                4222 non-null   float64
#  10  fbid               6036 non-null   int64
#  11  quickblox_id       6036 non-null   int64
#  12  steam_id           6036 non-null   int64
#  13  psn_id             6036 non-null   int64
#  14  xboxlive_id        6036 non-null   int64
#  15  nintendo_id        6036 non-null   int64
#  16  gamecenter_id      6036 non-null   int64
#  17  googleplay_id      6036 non-null   int64
#  18  battlenet_id       6036 non-null   int64
#  19  uplay_id           6036 non-null   int64
#  20  origin_id          6036 non-null   int64
#  21  youtube_id         6036 non-null   int64
#  22  twitch_id          6036 non-null   int64
#  23  phone_number       6036 non-null   int64
#  24  creation_datetime  6036 non-null   object
#  25  last_login         6036 non-null   object
#  26  last_interaction   6036 non-null   object
#  27  qtde_games         6036 non-null   float64
#  28  qtde_grupos        6036 non-null   float64
#  29  qtde_contatos      6036 non-null   float64
#  30  qtde_eventos       6036 non-null   float64
#  31  qtde_mensagens     6036 non-null   float64
#  32  qtde_plataformas   6036 non-null   float64
#  33  qtde_acessos       6036 non-null   float64
#  34  inatividade        6036 non-null   object
#  35  inatividade_days   6036 non-null   int64
#  36  tempo_uso          6036 non-null   object
#  37  tempo_uso_days     6036 non-null   int64
#  38  pouco_uso          6036 non-null   bool
# dtypes: bool(1), float64(9), int64(24), object(5)
# memory usage: 1.8+ MB

# %% [markdown]
# ### Vamos excluir as colunas 'object' que não serão utilizadas.

# %%
# Agora vamos criar um dataset de trabalho para podermos testar os modelos.
# E já vamos tirar a coluna de target para ser a base do train_test_split.
X = gg_train.drop(columns=['churn', 
                           'creation_datetime', 
                           'last_login', 
                           'last_interaction', 
                           'inatividade', 
                           'tempo_uso'])

# %%
# Vamos fazer o mesmo com o dataframe de teste desconhecido.
gg_test = gg_test.drop(columns=['creation_datetime', 
                                'last_login', 
                                'last_interaction', 
                                'inatividade', 
                                'tempo_uso'])

# %%
# Vamos definir o user_id como index nos dois dataframes.
X.set_index('user_id', inplace=True)
gg_test.set_index('user_id', inplace=True)

# %%
X.corr()
# Out:
#                      email      name  nickname    avatar  profile_pic_id  \
# email             1.000000 -0.236393 -0.088042 -0.229020       -0.230841
# name             -0.236393  1.000000  0.093463  0.945728        0.940518
# nickname         -0.088042  0.093463  1.000000  0.093345        0.090389
# avatar           -0.229020  0.945728  0.093345  1.000000        0.991824
# profile_pic_id   -0.230841  0.940518  0.090389  0.991824        1.000000
# city              0.044896  0.156525  0.063367  0.107878        0.087939
# ip_country_code  -0.000694  0.027364 -0.014444  0.032326        0.031844
# lat               0.146565  0.277665 -0.162835  0.257856        0.261000
# lng               0.151390  0.321987 -0.206532  0.304683        0.308349
# fbid             -0.253537  0.934130  0.068550  0.903300        0.910481
# quickblox_id     -0.099940  0.185398  0.723295  0.175856        0.171726
# steam_id          0.019913  0.031440  0.028105  0.038276        0.038845
# psn_id            0.022307  0.037406  0.031484  0.032932        0.028571
# xboxlive_id       0.019792  0.038269  0.027935  0.039561        0.038247
# nintendo_id       0.007861  0.009075  0.011095  0.012783        0.013010
# gamecenter_id     0.007861  0.013769  0.011095  0.017494        0.017717
# googleplay_id     0.017336  0.042196  0.024469  0.037920        0.038412
# battlenet_id      0.009753  0.019412  0.013765  0.021996        0.022272
# uplay_id          0.010685  0.017121  0.015081  0.019243        0.019550
# origin_id         0.008991  0.015432  0.012690  0.018423        0.018680
# youtube_id        0.018014  0.035033  0.025426  0.030722        0.027118
# twitch_id         0.016775  0.035153  0.023676  0.033070        0.033550
# phone_number      0.106013 -0.446941 -0.076493 -0.401345       -0.397751
# qtde_games       -0.027747  0.032636  0.058656  0.036606        0.035194
# qtde_grupos       0.003264  0.000037  0.042630  0.008167        0.000988
# qtde_contatos     0.029315  0.015306  0.037149  0.033541        0.031123
# qtde_eventos     -0.073599  0.083605  0.144150  0.110332        0.103108
# qtde_mensagens   -0.009438  0.014113  0.020330  0.010149        0.008463
# qtde_plataformas  0.010515  0.041432  0.141098  0.036201        0.035585
# qtde_acessos      0.009470  0.081124  0.017190  0.079452        0.079442
# inatividade_days -0.135362  0.007630 -0.036147  0.014255        0.015872
# tempo_uso_days   -0.226253  0.051930  0.197600  0.056537        0.056498
# pouco_uso         0.195715 -0.048887 -0.204564 -0.052455       -0.052120
#
#                       city  ip_country_code       lat       lng      fbid  \
# email             0.044896        -0.000694  0.146565  0.151390 -0.253537
# name              0.156525         0.027364  0.277665  0.321987  0.934130
# nickname          0.063367        -0.014444 -0.162835 -0.206532  0.068550
# avatar            0.107878         0.032326  0.257856  0.304683  0.903300
# profile_pic_id    0.087939         0.031844  0.261000  0.308349  0.910481
# city              1.000000         0.016402 -0.049600 -0.070768 -0.081837
# ip_country_code   0.016402         1.000000 -0.261225 -0.303611  0.024585
# lat              -0.049600        -0.261225  1.000000  0.770188  0.300881
# lng              -0.070768        -0.303611  0.770188  1.000000  0.353547
# fbid             -0.081837         0.024585  0.300881  0.353547  1.000000
# quickblox_id      0.086561         0.054971 -0.149903 -0.183552  0.151105
# steam_id          0.118750        -0.004005 -0.006797 -0.030395  0.001252
# psn_id            0.137592         0.004415 -0.032530 -0.036149 -0.001715
# xboxlive_id       0.119630         0.001508 -0.029655 -0.039488  0.002212
# nintendo_id       0.022473        -0.009144  0.011216 -0.018169  0.001734
# gamecenter_id     0.050223        -0.023411  0.004444 -0.018970 -0.002943
# googleplay_id     0.127271        -0.014673  0.000705 -0.022366  0.003988
# battlenet_id      0.038210        -0.005150 -0.010057 -0.032125  0.006794
# uplay_id          0.043906        -0.003541 -0.011410 -0.035333 -0.007709
# origin_id         0.054640        -0.006619  0.001179 -0.023540  0.005445
# youtube_id        0.109478        -0.007012 -0.019911 -0.039698 -0.011630
# twitch_id         0.112688        -0.002485 -0.024596 -0.036468 -0.006787
# phone_number     -0.071157        -0.055607 -0.142228 -0.160128 -0.417731
# qtde_games        0.056054         0.016525 -0.036833 -0.030190  0.011606
# qtde_grupos       0.083144         0.014720 -0.024195 -0.044489 -0.031845
# qtde_contatos     0.085789         0.009735 -0.032643 -0.045281 -0.010220
# qtde_eventos      0.177974         0.041266 -0.081139 -0.103299  0.026860
# qtde_mensagens    0.065161         0.002974 -0.009379 -0.007304 -0.009516
# qtde_plataformas  0.031680         0.014967 -0.021207 -0.022780  0.028686
# qtde_acessos      0.038526         0.030292  0.022397  0.028642  0.066866
# inatividade_days -0.019540         0.079216 -0.072134 -0.054501  0.014200
# tempo_uso_days    0.007989        -0.008199 -0.058069 -0.066554  0.044724
# pouco_uso        -0.017323        -0.008096  0.053000  0.069220 -0.038147
#
#                   quickblox_id  steam_id    psn_id  xboxlive_id  nintendo_id  \
# email                -0.099940  0.019913  0.022307     0.019792     0.007861
# name                  0.185398  0.031440  0.037406     0.038269     0.009075
# nickname              0.723295  0.028105  0.031484     0.027935     0.011095
# avatar                0.175856  0.038276  0.032932     0.039561     0.012783
# profile_pic_id        0.171726  0.038845  0.028571     0.038247     0.013010
# city                  0.086561  0.118750  0.137592     0.119630     0.022473
# ip_country_code       0.054971 -0.004005  0.004415     0.001508    -0.009144
# lat                  -0.149903 -0.006797 -0.032530    -0.029655     0.011216
# lng                  -0.183552 -0.030395 -0.036149    -0.039488    -0.018169
# fbid                  0.151105  0.001252 -0.001715     0.002212     0.001734
# quickblox_id          1.000000  0.038857  0.041467     0.038621     0.015340
# steam_id              0.038857  1.000000  0.318415     0.323315     0.364228
# psn_id                0.041467  0.318415  1.000000     0.211413     0.325098
# xboxlive_id           0.038621  0.323315  0.211413     1.000000     0.366457
# nintendo_id           0.015340  0.364228  0.325098     0.366457     1.000000
# gamecenter_id         0.015340  0.272586  0.243168     0.274261     0.692023
# googleplay_id         0.031184  0.300662  0.217920     0.330512     0.383374
# battlenet_id          0.019032  0.465146  0.283053     0.294511     0.619755
# uplay_id              0.020851  0.424148  0.277941     0.268362     0.565627
# origin_id             0.017544  0.398073  0.259740     0.292999     0.604994
# youtube_id            0.035153  0.315820  0.352923     0.250476     0.335190
# twitch_id             0.032733  0.425881  0.353937     0.284022     0.360033
# phone_number         -0.331844 -0.028917 -0.035355    -0.028709    -0.005797
# qtde_games            0.079759  0.085004  0.048699     0.050219     0.013241
# qtde_grupos           0.056878  0.055406  0.025217     0.059991     0.057997
# qtde_contatos         0.037988  0.030177  0.022214     0.022936     0.013637
# qtde_eventos          0.167575  0.078636  0.088750     0.058674     0.047332
# qtde_mensagens        0.028107  0.009441  0.044292    -0.004262    -0.001693
# qtde_plataformas      0.196400  0.008292  0.006988     0.015030     0.015081
# qtde_acessos          0.021579 -0.007265  0.011728     0.000550    -0.004168
# inatividade_days     -0.148323 -0.010883  0.013724    -0.017722    -0.003603
# tempo_uso_days       -0.059432  0.017476  0.050186     0.011490    -0.001343
# pouco_uso            -0.002602 -0.024282 -0.050842    -0.020576     0.000586
#
#                   gamecenter_id  googleplay_id  battlenet_id  uplay_id  \
# email                  0.007861       0.017336      0.009753  0.010685
# name                   0.013769       0.042196      0.019412  0.017121
# nickname               0.011095       0.024469      0.013765  0.015081
# avatar                 0.017494       0.037920      0.021996  0.019243
# profile_pic_id         0.017717       0.038412      0.022272  0.019550
# city                   0.050223       0.127271      0.038210  0.043906
# ip_country_code       -0.023411      -0.014673     -0.005150 -0.003541
# lat                    0.004444       0.000705     -0.010057 -0.011410
# lng                   -0.018970      -0.022366     -0.032125 -0.035333
# fbid                  -0.002943       0.003988      0.006794 -0.007709
# quickblox_id           0.015340       0.031184      0.019032  0.020851
# steam_id               0.272586       0.300662      0.465146  0.424148
# psn_id                 0.243168       0.217920      0.283053  0.277941
# xboxlive_id            0.274261       0.330512      0.294511  0.268362
# nintendo_id            0.692023       0.383374      0.619755  0.565627
# gamecenter_id          1.000000       0.383374      0.557665  0.508939
# googleplay_id          0.383374       1.000000      0.308278  0.332591
# battlenet_id           0.557665       0.308278      1.000000  0.684166
# uplay_id               0.508939       0.332591      0.684166  1.000000
# origin_id              0.672333       0.365394      0.704640  0.593518
# youtube_id             0.335190       0.379073      0.242185  0.319975
# twitch_id              0.396234       0.325125      0.464643  0.477079
# phone_number          -0.012459      -0.027477     -0.010085 -0.012030
# qtde_games             0.004076       0.032247      0.037462  0.036164
# qtde_grupos            0.037319       0.056966      0.028342  0.024962
# qtde_contatos          0.012053       0.033808      0.005257  0.004360
# qtde_eventos           0.029915       0.086855      0.035764  0.031169
# qtde_mensagens        -0.001693       0.004140     -0.002100 -0.002301
# qtde_plataformas       0.020865       0.019897      0.009154  0.008945
# qtde_acessos          -0.001401       0.008437     -0.005172 -0.005666
# inatividade_days      -0.001697      -0.014968      0.004953  0.006690
# tempo_uso_days        -0.003136      -0.002601      0.011697  0.020867
# pouco_uso              0.006069      -0.002354     -0.014237 -0.025286
#
#                   origin_id  youtube_id  twitch_id  phone_number  qtde_games  \
# email              0.008991    0.018014   0.016775      0.106013   -0.027747
# name               0.015432    0.035033   0.035153     -0.446941    0.032636
# nickname           0.012690    0.025426   0.023676     -0.076493    0.058656
# avatar             0.018423    0.030722   0.033070     -0.401345    0.036606
# profile_pic_id     0.018680    0.027118   0.033550     -0.397751    0.035194
# city               0.054640    0.109478   0.112688     -0.071157    0.056054
# ip_country_code   -0.006619   -0.007012  -0.002485     -0.055607    0.016525
# lat                0.001179   -0.019911  -0.024596     -0.142228   -0.036833
# lng               -0.023540   -0.039698  -0.036468     -0.160128   -0.030190
# fbid               0.005445   -0.011630  -0.006787     -0.417731    0.011606
# quickblox_id       0.017544    0.035153   0.032733     -0.331844    0.079759
# steam_id           0.398073    0.315820   0.425881     -0.028917    0.085004
# psn_id             0.259740    0.352923   0.353937     -0.035355    0.048699
# xboxlive_id        0.292999    0.250476   0.284022     -0.028709    0.050219
# nintendo_id        0.604994    0.335190   0.360033     -0.005797    0.013241
# gamecenter_id      0.672333    0.335190   0.396234     -0.012459    0.004076
# googleplay_id      0.365394    0.379073   0.325125     -0.027477    0.032247
# battlenet_id       0.704640    0.242185   0.464643     -0.010085    0.037462
# uplay_id           0.593518    0.319975   0.477079     -0.012030    0.036164
# origin_id          1.000000    0.292587   0.440998     -0.014250    0.033641
# youtube_id         0.292587    1.000000   0.550555     -0.028551    0.030187
# twitch_id          0.440998    0.550555   1.000000     -0.023454    0.038363
# phone_number      -0.014250   -0.028551  -0.023454      1.000000   -0.049229
# qtde_games         0.033641    0.030187   0.038363     -0.049229    1.000000
# qtde_grupos        0.031553    0.031514   0.035136     -0.016863    0.064431
# qtde_contatos      0.006786    0.029329   0.014852      0.024547    0.063005
# qtde_eventos       0.035826    0.088950   0.094780     -0.032489    0.090704
# qtde_mensagens    -0.001936    0.018860   0.012657     -0.010852    0.024023
# qtde_plataformas   0.017107    0.017922   0.014249     -0.145935    0.123860
# qtde_acessos      -0.002347   -0.005915  -0.003691     -0.048552    0.034339
# inatividade_days  -0.001767   -0.008550   0.001582      0.004978   -0.036706
# tempo_uso_days     0.010666    0.009590   0.026419      0.008409    0.027523
# pouco_uso         -0.014083   -0.011405  -0.025518     -0.011290   -0.033455
#
#                   qtde_grupos  qtde_contatos  qtde_eventos  qtde_mensagens  \
# email                0.003264       0.029315     -0.073599       -0.009438
# name                 0.000037       0.015306      0.083605        0.014113
# nickname             0.042630       0.037149      0.144150        0.020330
# avatar               0.008167       0.033541      0.110332        0.010149
# profile_pic_id       0.000988       0.031123      0.103108        0.008463
# city                 0.083144       0.085789      0.177974        0.065161
# ip_country_code      0.014720       0.009735      0.041266        0.002974
# lat                 -0.024195      -0.032643     -0.081139       -0.009379
# lng                 -0.044489      -0.045281     -0.103299       -0.007304
# fbid                -0.031845      -0.010220      0.026860       -0.009516
# quickblox_id         0.056878       0.037988      0.167575        0.028107
# steam_id             0.055406       0.030177      0.078636        0.009441
# psn_id               0.025217       0.022214      0.088750        0.044292
# xboxlive_id          0.059991       0.022936      0.058674       -0.004262
# nintendo_id          0.057997       0.013637      0.047332       -0.001693
# gamecenter_id        0.037319       0.012053      0.029915       -0.001693
# googleplay_id        0.056966       0.033808      0.086855        0.004140
# battlenet_id         0.028342       0.005257      0.035764       -0.002100
# uplay_id             0.024962       0.004360      0.031169       -0.002301
# origin_id            0.031553       0.006786      0.035826       -0.001936
# youtube_id           0.031514       0.029329      0.088950        0.018860
# twitch_id            0.035136       0.014852      0.094780        0.012657
# phone_number        -0.016863       0.024547     -0.032489       -0.010852
# qtde_games           0.064431       0.063005      0.090704        0.024023
# qtde_grupos          1.000000       0.083312      0.295075        0.015837
# qtde_contatos        0.083312       1.000000      0.155923        0.015786
# qtde_eventos         0.295075       0.155923      1.000000        0.106146
# qtde_mensagens       0.015837       0.015786      0.106146        1.000000
# qtde_plataformas     0.058655       0.059146      0.053078        0.019699
# qtde_acessos         0.016344       0.027436      0.043602        0.526517
# inatividade_days    -0.041571      -0.032123      0.003357       -0.024330
# tempo_uso_days      -0.028658      -0.031123      0.060340        0.039762
# pouco_uso            0.021419       0.033078     -0.057728       -0.026693
#
#                   qtde_plataformas  qtde_acessos  inatividade_days  \
# email                     0.010515      0.009470         -0.135362
# name                      0.041432      0.081124          0.007630
# nickname                  0.141098      0.017190         -0.036147
# avatar                    0.036201      0.079452          0.014255
# profile_pic_id            0.035585      0.079442          0.015872
# city                      0.031680      0.038526         -0.019540
# ip_country_code           0.014967      0.030292          0.079216
# lat                      -0.021207      0.022397         -0.072134
# lng                      -0.022780      0.028642         -0.054501
# fbid                      0.028686      0.066866          0.014200
# quickblox_id              0.196400      0.021579         -0.148323
# steam_id                  0.008292     -0.007265         -0.010883
# psn_id                    0.006988      0.011728          0.013724
# xboxlive_id               0.015030      0.000550         -0.017722
# nintendo_id               0.015081     -0.004168         -0.003603
# gamecenter_id             0.020865     -0.001401         -0.001697
# googleplay_id             0.019897      0.008437         -0.014968
# battlenet_id              0.009154     -0.005172          0.004953
# uplay_id                  0.008945     -0.005666          0.006690
# origin_id                 0.017107     -0.002347         -0.001767
# youtube_id                0.017922     -0.005915         -0.008550
# twitch_id                 0.014249     -0.003691          0.001582
# phone_number             -0.145935     -0.048552          0.004978
# qtde_games                0.123860      0.034339         -0.036706
# qtde_grupos               0.058655      0.016344         -0.041571
# qtde_contatos             0.059146      0.027436         -0.032123
# qtde_eventos              0.053078      0.043602          0.003357
# qtde_mensagens            0.019699      0.526517         -0.024330
# qtde_plataformas          1.000000      0.029334         -0.066730
# qtde_acessos              0.029334      1.000000          0.032924
# inatividade_days         -0.066730      0.032924          1.000000
# tempo_uso_days           -0.063716      0.025593          0.517194
# pouco_uso                 0.042645     -0.003933         -0.306656
#
#                   tempo_uso_days  pouco_uso
# email                  -0.226253   0.195715
# name                    0.051930  -0.048887
# nickname                0.197600  -0.204564
# avatar                  0.056537  -0.052455
# profile_pic_id          0.056498  -0.052120
# city                    0.007989  -0.017323
# ip_country_code        -0.008199  -0.008096
# lat                    -0.058069   0.053000
# lng                    -0.066554   0.069220
# fbid                    0.044724  -0.038147
# quickblox_id           -0.059432  -0.002602
# steam_id                0.017476  -0.024282
# psn_id                  0.050186  -0.050842
# xboxlive_id             0.011490  -0.020576
# nintendo_id            -0.001343   0.000586
# gamecenter_id          -0.003136   0.006069
# googleplay_id          -0.002601  -0.002354
# battlenet_id            0.011697  -0.014237
# uplay_id                0.020867  -0.025286
# origin_id               0.010666  -0.014083
# youtube_id              0.009590  -0.011405
# twitch_id               0.026419  -0.025518
# phone_number            0.008409  -0.011290
# qtde_games              0.027523  -0.033455
# qtde_grupos            -0.028658   0.021419
# qtde_contatos          -0.031123   0.033078
# qtde_eventos            0.060340  -0.057728
# qtde_mensagens          0.039762  -0.026693
# qtde_plataformas       -0.063716   0.042645
# qtde_acessos            0.025593  -0.003933
# inatividade_days        0.517194  -0.306656
# tempo_uso_days          1.000000  -0.875095
# pouco_uso              -0.875095   1.000000

# %%
fig, ax = plt.subplots(figsize=(15, 12))
plt.grid(False)
sns.set(font_scale=0.7)

sns.heatmap(X.corr().round(2), annot=True, vmin=-1, vmax=1, cmap='coolwarm', ax=ax)
plt.savefig('../Imagens/corr_all_X')

# %%
X.drop(columns=['profile_pic_id', 
                'avatar', 
                'ip_country_code', 
                'psn_id', 
                'xboxlive_id', 
                'nintendo_id', 
                'gamecenter_id', 
                'googleplay_id', 
                'battlenet_id', 
                'uplay_id', 
                'origin_id', 
                'youtube_id', 
                'twitch_id'], inplace=True)

# %%
gg_test.drop(columns=['profile_pic_id', 
                      'avatar', 
                      'ip_country_code', 
                      'psn_id', 
                      'xboxlive_id', 
                      'nintendo_id', 
                      'gamecenter_id', 
                      'googleplay_id', 
                      'battlenet_id', 
                      'uplay_id', 
                      'origin_id', 
                      'youtube_id', 
                      'twitch_id'], inplace=True)

# %%
X.isnull().sum()
# Out:
# email                  0
# name                   0
# nickname               0
# city                   0
# lat                 4104
# lng                 4104
# fbid                   0
# quickblox_id           0
# steam_id               0
# phone_number           0
# qtde_games             0
# qtde_grupos            0
# qtde_contatos          0
# qtde_eventos           0
# qtde_mensagens         0
# qtde_plataformas       0
# qtde_acessos           0
# inatividade_days       0
# tempo_uso_days         0
# pouco_uso              0
# dtype: int64

# %%
# Vamos preencher os valores nulos do dataset.
X['lat'].fillna(method='ffill', inplace=True)
X['lng'].fillna(method='ffill', inplace=True)
gg_test['lat'].fillna(method='ffill', inplace=True)
gg_test['lng'].fillna(method='ffill', inplace=True)

# %%
fig, ax = plt.subplots(figsize=(15, 12))
plt.grid(False)
sns.set(font_scale=1)

sns.heatmap(X.corr().round(2), annot=True, vmin=-1, vmax=1, cmap='coolwarm', ax=ax)
plt.savefig('../Imagens/corr_sel_X')

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14084 entries, 51077 to 71195
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   email             14084 non-null  int64
#  1   name              14084 non-null  int64
#  2   nickname          14084 non-null  int64
#  3   city              14084 non-null  int64
#  4   lat               14084 non-null  float64
#  5   lng               14084 non-null  float64
#  6   fbid              14084 non-null  int64
#  7   quickblox_id      14084 non-null  int64
#  8   steam_id          14084 non-null  int64
#  9   phone_number      14084 non-null  int64
#  10  qtde_games        14084 non-null  float64
#  11  qtde_grupos       14084 non-null  float64
#  12  qtde_contatos     14084 non-null  float64
#  13  qtde_eventos      14084 non-null  float64
#  14  qtde_mensagens    14084 non-null  float64
#  15  qtde_plataformas  14084 non-null  float64
#  16  qtde_acessos      14084 non-null  float64
#  17  inatividade_days  14084 non-null  int64
#  18  tempo_uso_days    14084 non-null  int64
#  19  pouco_uso         14084 non-null  bool
# dtypes: bool(1), float64(9), int64(10)
# memory usage: 2.2 MB

# %%
X_plot = gg_train[['email', 
                   'name', 
                   'nickname', 
                   'city', 
                   'lat', 
                   'lng', 
                   'fbid', 
                   'quickblox_id', 
                   'steam_id', 
                   'phone_number', 
                   'qtde_games', 
                   'qtde_grupos', 
                   'qtde_contatos', 
                   'qtde_eventos', 
                   'qtde_mensagens', 
                   'qtde_plataformas', 
                   'qtde_acessos', 
                   'inatividade_days', 
                   'tempo_uso_days', 
                   'churn']
                 ]

# %%
y = gg_train['churn']

# %% [markdown]
# ### Vamos verificar o balanceamento das classes.

# %%
target_count = gg_train.churn.value_counts()
print('Class 0:', target_count[0])
print('Class 1:', target_count[1])
print('Proportion:', round(target_count[0] / target_count[1], 4), ':1')

target_count.plot(figsize=(10, 8), kind='bar', fontsize=16);
plt.title(label='Balanceamento das Classes Inicial (target)', fontsize=16, pad=10)
plt.savefig('../Imagens/bal_classes_init')
# Out:
# Class 0: 158
# Class 1: 13926
# Proportion: 0.0113 :1

# %% [markdown]
# ### Vamos tentar melhorar o balanceamento das classes usando o ADASYN

# %%
print("Divisão das Classes original %s" % Counter(y))

adasyn = ADASYN(sampling_strategy=0.2, random_state=18)
X_ada, y_ada = adasyn.fit_resample(X, y)

print('Divisão das Classes ajustada %s' % Counter(y_ada))
# Out:
# Original Dataset shape Counter({True: 13926, False: 158})
# Resampled Dataset shape Counter({True: 13926, False: 2787})

# %%
# Vamos verificar o balanceamento agora.
gg_ada = pd.concat([X_ada, y_ada], axis=1)
target_count = gg_ada.churn.value_counts()
print('Class 0:', target_count[0])
print('Class 1:', target_count[1])
print('Proportion:', round(target_count[0] / target_count[1], 4), ':1')

target_count.plot(figsize=(10, 8), kind='bar', fontsize=16);
plt.title(label='Balanceamento das Classes Ajustado (target)', fontsize=16, pad=10)
plt.savefig('../Imagens/bal_classes_adj')
# Out:
# Class 0: 2787
# Class 1: 13926
# Proportion: 0.2001 :1

# %% [markdown]
# ### Vamos verificar se as features que restaram são todas relevantes para utilizar treino do modelo.

# %%
gg_t_email = pd.crosstab(gg_ada['email'],gg_ada['churn'])
gg_t_email.div(gg_t_email.sum(1).astype(float), axis=0).plot(figsize=(12, 8), kind='bar', stacked=True)
plt.legend(loc='upper left', bbox_to_anchor=(1, 0.5))
plt.title('Frequência de Churn por Presença de E-mail')
plt.xlabel('Presença de E-mail (1 = Sim)')
plt.ylabel('Frequência de Churn')
plt.savefig('../Imagens/churn_email_bar')

# %%
gg_t_name = pd.crosstab(gg_ada['name'],gg_ada['churn'])
gg_t_name.div(gg_t_name.sum(1).astype(float), axis=0).plot(figsize=(12, 8), kind='bar', stacked=True)
plt.legend(loc='upper left', bbox_to_anchor=(1, 0.5))
plt.title('Frequência de Churn por Presença de Nome')
plt.xlabel('Presença de Nome (1= Sim)')
plt.ylabel('Frequência de Churn')
plt.savefig('../Imagens/churn_nome_bar')

# %%
gg_t_nick = pd.crosstab(gg_ada['nickname'],gg_ada['churn'])
gg_t_nick.div(gg_t_nick.sum(1).astype(float), axis=0).plot(figsize=(12, 8), kind='bar', stacked=True)
plt.legend(loc='upper left', bbox_to_anchor=(1, 0.5))
plt.title('Frequência de Churn por Presença de Nickname')
plt.xlabel('Presença de Nickname (1= Sim)')
plt.ylabel('Frequência de Churn')
plt.savefig('../Imagens/churn_nick_bar')

# %%
gg_t_city = pd.crosstab(gg_ada['city'],gg_ada['churn'])
gg_t_city.div(gg_t_city.sum(1).astype(float), axis=0).plot(figsize=(12, 8), kind='bar', stacked=True)
plt.legend(loc='upper left', bbox_to_anchor=(1, 0.5))
plt.title('Frequência de Churn por Presença de Cidade')
plt.xlabel('Presença de Cidade (1= Sim)')
plt.ylabel('Frequência de Churn')
plt.savefig('../Imagens/churn_city_bar')

# %%
gg_t_lat = gg_ada.copy()
gg_t_lat['bin']=pd.cut(gg_t_lat.lat,bins=10)
table_lat = pd.crosstab(gg_t_lat['bin'],gg_t_lat['churn'])
table_lat.div(table_lat.sum(1).astype(float), axis=0).plot(figsize=(12, 8), kind='bar', stacked=True)
plt.legend(loc='upper left', bbox_to_anchor=(1, 0.5))
plt.title('Frequência de Churn por Latitude (agrupados)')
plt.xlabel('Agrupamentos de Latitude')
plt.ylabel('Frequência de Churn')
plt.savefig('../Imagens/churn_lat_bar')

# %%
gg_t_lng = gg_ada.copy()
gg_t_lng['bin']=pd.cut(gg_t_lng.lng,bins=10)
table_lng = pd.crosstab(gg_t_lng['bin'],gg_t_lng['churn'])
table_lng.div(table_lng.sum(1).astype(float), axis=0).plot(figsize=(12, 8), kind='bar', stacked=True)
plt.legend(loc='upper left', bbox_to_anchor=(1, 0.5))
plt.title('Frequência de Churn por Longitude (agrupados)')
plt.xlabel('Agrupamentos de Longitude')
plt.ylabel('Frequência de Churn')
plt.savefig('../Imagens/churn_lng_bar')

# %%
gg_t_fbid = pd.crosstab(gg_ada['fbid'],gg_ada['churn'])
gg_t_fbid.div(gg_t_fbid.sum(1).astype(float), axis=0).plot(figsize=(12, 8), kind='bar', stacked=True)
plt.legend(loc='upper left', bbox_to_anchor=(1, 0.5))
plt.title('Frequência de Churn por Inserção de ID do Facebook')
plt.xlabel('Inserção de ID do Facebook (1= Sim)')
plt.ylabel('Frequência de Churn')
plt.savefig('../Imagens/churn_fbid_bar')

# %%
gg_t_quick = pd.crosstab(gg_ada['quickblox_id'],gg_ada['churn'])
gg_t_quick.div(gg_t_quick.sum(1).astype(float), axis=0).plot(figsize=(12, 8), kind='bar', stacked=True)
plt.legend(loc='upper left', bbox_to_anchor=(1, 0.5))
plt.title('Frequência de Churn por Inserção de ID do Quickblox')
plt.xlabel('Inserção de ID do Quickblox (1= Sim)')
plt.ylabel('Frequência de Churn')
plt.savefig('../Imagens/churn_quick_bar')

# %%
gg_t_steam = pd.crosstab(gg_ada['steam_id'],gg_ada['churn'])
gg_t_steam.div(gg_t_steam.sum(1).astype(float), axis=0).plot(figsize=(12, 8), kind='bar', stacked=True)
plt.legend(loc='upper left', bbox_to_anchor=(1, 0.5))
plt.title('Frequência de Churn por Inserção de ID da Steam')
plt.xlabel('Inserção de ID da Steam (1= Sim)')
plt.ylabel('Frequência de Churn')
plt.savefig('../Imagens/churn_steam_bar')

# %%
gg_t_phone = pd.crosstab(gg_ada['phone_number'],gg_ada['churn'])
gg_t_phone.div(gg_t_phone.sum(1).astype(float), axis=0).plot(figsize=(12, 8), kind='bar', stacked=True)
plt.legend(loc='upper left', bbox_to_anchor=(1, 0.5))
plt.title('Frequência de Churn por Inserção de N. de Telefone')
plt.xlabel('Inserção de N. de Telefone (1= Sim)')
plt.ylabel('Frequência de Churn')
plt.savefig('../Imagens/churn_phone_bar')

# %%
gg_t_games = gg_ada.loc[gg_ada['qtde_games'] <= 10]
gg_t_games['bin']=pd.cut(gg_t_games.qtde_games,bins=5)
table_games = pd.crosstab(gg_t_games['bin'],gg_t_games['churn'])
table_games.div(table_games.sum(1).astype(float), axis=0).plot(figsize=(12, 8), kind='bar', stacked=True)
plt.legend(loc='upper left', bbox_to_anchor=(1, 0.5))
plt.title('Frequência de Churn por Quantidade de Jogos Cadastrados')
plt.xlabel('Quantidade de Jogos')
plt.ylabel('Frequência de Churn')
plt.savefig('../Imagens/churn_games_bar')

# %%
gg_t_grupos = gg_ada.loc[gg_ada['qtde_grupos'] <= 10]
gg_t_grupos['bin']=pd.cut(gg_t_grupos.qtde_grupos,bins=5)
table_grupos = pd.crosstab(gg_t_grupos['bin'],gg_t_grupos['churn'])
table_grupos.div(table_grupos.sum(1).astype(float), axis=0).plot(figsize=(12, 8), kind='bar', stacked=True)
plt.legend(loc='upper left', bbox_to_anchor=(1, 0.5))
plt.title('Frequência de Churn por Quantidade de Jogos Cadastrados')
plt.xlabel('Quantidade de Jogos')
plt.ylabel('Frequência de Churn')
plt.savefig('../Imagens/churn_grupos_bar')

# %%
gg_t_contatos = gg_ada.loc[gg_ada['qtde_contatos'] <= 20]
gg_t_contatos['bin']=pd.cut(gg_t_contatos.qtde_contatos,bins=5)
table_cont = pd.crosstab(gg_t_contatos['bin'],gg_t_contatos['churn'])
table_cont.div(table_cont.sum(1).astype(float), axis=0).plot(figsize=(12, 8), kind='bar', stacked=True)
plt.legend(loc='upper left', bbox_to_anchor=(1, 0.5))
plt.title('Frequência de Churn por Quantidade de Contatos')
plt.xlabel('Quantidade de Contatos')
plt.ylabel('Frequência de Churn')
plt.savefig('../Imagens/churn_contatos_bar')

# %%
gg_t_eventos = gg_ada.loc[gg_ada['qtde_eventos'] <= 10]
gg_t_eventos['bin']=pd.cut(gg_t_eventos.qtde_eventos,bins=5)
table_eventos = pd.crosstab(gg_t_eventos['bin'],gg_t_eventos['churn'])
table_eventos.div(table_eventos.sum(1).astype(float), axis=0).plot(figsize=(12, 8), kind='bar', stacked=True)
plt.legend(loc='upper left', bbox_to_anchor=(1, 0.5))
plt.title('Frequência de Churn por Quantidade de Eventos')
plt.xlabel('Quantidade de Eventos')
plt.ylabel('Frequência de Churn')
plt.savefig('../Imagens/churn_events_bar')

# %%
gg_t_mens = gg_ada.loc[gg_ada['qtde_mensagens'] <= 20]
gg_t_mens['bin']=pd.cut(gg_t_mens.qtde_mensagens,bins=5)
table_mens = pd.crosstab(gg_t_mens['bin'],gg_t_mens['churn'])
table_mens.div(table_mens.sum(1).astype(float), axis=0).plot(figsize=(12, 8), kind='bar', stacked=True)
plt.legend(loc='upper left', bbox_to_anchor=(1, 0.5))
plt.title('Frequência de Churn por Quantidade de Mensagens')
plt.xlabel('Quantidade de Mensagens')
plt.ylabel('Frequência de Churn')
plt.savefig('../Imagens/churn_mens_bar')

# %%
gg_t_plat = gg_ada.loc[gg_ada['qtde_plataformas'] <= 30]
gg_t_plat['bin']=pd.cut(gg_t_plat.qtde_plataformas,bins=5)
table_plat = pd.crosstab(gg_t_plat['bin'],gg_t_plat['churn'])
table_plat.div(table_plat.sum(1).astype(float), axis=0).plot(figsize=(12, 8), kind='bar', stacked=True)
plt.legend(loc='upper left', bbox_to_anchor=(1, 0.5))
plt.title('Frequência de Churn por Quantidade de Plataformas')
plt.xlabel('Quantidade de Plataformas')
plt.ylabel('Frequência de Churn')
plt.savefig('../Imagens/churn_plat_bar')

# %%
gg_t_acessos = gg_ada.loc[gg_ada['qtde_acessos'] <= 20]
gg_t_acessos['bin']=pd.cut(gg_t_acessos.qtde_acessos, bins=5)
table_acess = pd.crosstab(gg_t_acessos['bin'],gg_t_acessos['churn'])
table_acess.div(table_acess.sum(1).astype(float), axis=0).plot(figsize=(12, 8), kind='bar', stacked=True)
plt.legend(loc='upper left', bbox_to_anchor=(1, 0.5))
plt.title('Frequência de Churn por Quantidade de Acessos')
plt.xlabel('Quantidade de Acessos')
plt.ylabel('Frequência de Churn')
plt.savefig('../Imagens/churn_acessos_bar')

# %%
gg_t_inat = gg_ada.loc[gg_ada['inatividade_days'] <= 100]
gg_t_inat['bin']=pd.cut(gg_t_inat.inatividade_days, bins=10)
table_inat = pd.crosstab(gg_t_inat['bin'],gg_t_inat['churn'])
table_inat.div(table_inat.sum(1).astype(float), axis=0).plot(figsize=(12, 8), kind='bar', stacked=True)
plt.legend(loc='upper left', bbox_to_anchor=(1, 0.5))
plt.title('Frequência de Churn por Tempo de Inatividade (dias)')
plt.xlabel('Tempo de Inatividade (dias)')
plt.ylabel('Frequência de Churn')
plt.savefig('../Imagens/churn_inat_bar')

# %%
gg_t_uso = gg_ada.loc[gg_ada['tempo_uso_days'] <= 60]
gg_t_uso['bin']=pd.cut(gg_t_uso.tempo_uso_days, bins=6)
table_uso = pd.crosstab(gg_t_uso['bin'],gg_t_uso['churn'])
table_uso.div(table_uso.sum(1).astype(float), axis=0).plot(figsize=(12, 8), kind='bar', stacked=True)
plt.legend(loc='upper left', bbox_to_anchor=(1, 0.5))
plt.title('Frequência de Churn por Tempo de Uso do App (dias)')
plt.xlabel('Tempo de Uso (dias)')
plt.ylabel('Frequência de Churn')
plt.savefig('../Imagens/churn_uso_bar')

# %% [markdown]
# ### Vamos eliminar mais algumas colunas que não são significativas para treinar o modelo.

# %%
X_ada.drop(columns=['email', 
                    'inatividade_days', 
                    'pouco_uso'], inplace=True)

# %%
gg_test.drop(columns=['email', 
                    'inatividade_days', 
                    'pouco_uso'], inplace=True)

# %% [markdown]
# ### Agora vamos testar alguns modelos para encontrar as melhores opções.

# %%
# Separando o dataset em train e test para o churn de 30 dias.
X_train, X_test, y_train, y_test = train_test_split(X_ada, y_ada, test_size=0.25, random_state=18)

# %%
# Vamos testar o primeiro modelo, de Regressão Logística.
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(max_iter=1000).fit(X_train, y_train)
y_pred_lr = lr.predict(X_test)

# %%
# Plotando a matriz de confusão.
fig, ax = plt.subplots(figsize=(8, 8))
plt.grid(False)
sns.set(font_scale=1.3)
plot_confusion_matrix(lr, X_test, y_test, cmap='YlGnBu', ax=ax)
ax.set_xlabel('Valor Predito')
ax.set_ylabel('Valor Real')
ax.set_xticklabels(['Not churn', 'Churn'])
ax.set_yticklabels(['Not churn', 'Churn'])
ax.set_title(label='Matriz de Confusão - Regressão Logística', fontsize=14, pad=10)
plt.savefig('../Imagens/confmatrix_lr')

# %%
print(f'Acurácia: {accuracy_score(y_test, y_pred_lr).round(4)*100}%')
print(f'Precisão: {precision_score(y_test, y_pred_lr).round(4)*100}%')
print(f'Recall:   {recall_score(y_test, y_pred_lr).round(5)*100}%')
print(f'F1-Score: {f1_score(y_true=y_test, y_pred=y_pred_lr, average="weighted").round(5)*100}%')
# Out:
# Acurácia: 95.07%
# Precisão: 95.67%
# Recall:   98.571%
# F1-Score: 94.899%

# %%
fig, ax = plt.subplots(figsize=(10, 8))
plt.grid(False)
sns.set(font_scale=1.3)
plot_roc_curve(lr, X_test, y_test, ax=ax)
plt.title(label='Curva ROC - Regressão Logística', fontsize=14, pad=10)
plt.savefig('../Imagens/roc_lr')

# %%
svm = SVC(C=15.0, random_state=18)
svm.fit(X_train, y_train)

y_pred_svm = svm.predict(X_test)

# %%
# Plotando a matriz de confusão.
fig, ax = plt.subplots(figsize=(8, 8))
plt.grid(False)
sns.set(font_scale=1.3)
plot_confusion_matrix(svm, X_test, y_test, cmap='YlGnBu', ax=ax)
ax.set_xlabel('Valor Predito')
ax.set_ylabel('Valor Real')
ax.set_xticklabels(['Not churn', 'Churn'])
ax.set_yticklabels(['Not churn', 'Churn'])
ax.set_title(label='Matriz de Confusão - SVC', fontsize=14, pad=10)
plt.savefig('../Imagens/confmatrix_svm')

# %%
print(f'Acurácia: {accuracy_score(y_test, y_pred_svm).round(4)*100}%')
print(f'Precisão: {precision_score(y_test, y_pred_svm).round(4)*100}%')
print(f'Recall:   {recall_score(y_test, y_pred_svm).round(4)*100}%')
print(f'F1-Score: {f1_score(y_true=y_test, y_pred=y_pred_svm, average="weighted").round(4)*100}%')
# Out:
# Acurácia: 95.98%
# Precisão: 95.67%
# Recall:   99.71%
# F1-Score: 95.78%

# %%
fig, ax = plt.subplots(figsize=(10, 8))
plt.grid(False)
sns.set(font_scale=1.3)
plot_roc_curve(svm, X_test, y_test, ax=ax)
plt.title(label='Curva ROC - SVC', fontsize=14, pad=10)
plt.savefig('../Imagens/roc_svm')

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, y_train)
y_pred_knn = knn.predict(X_test)

# %%
# Plotando a matriz de confusão.
fig, ax = plt.subplots(figsize=(8, 8))
plt.grid(False)
sns.set(font_scale=1.3)
plot_confusion_matrix(knn, X_test, y_test, cmap='YlGnBu', ax=ax)
ax.set_xlabel('Valor Predito')
ax.set_ylabel('Valor Real')
ax.set_xticklabels(['Not churn', 'Churn'])
ax.set_yticklabels(['Not churn', 'Churn'])
ax.set_title(label='Matriz de Confusão - KNN', fontsize=14, pad=10)
plt.savefig('../Imagens/confmatrix_knn')

# %%
print(f'Acurácia: {accuracy_score(y_test, y_pred_knn).round(5)*100}%')
print(f'Precisão: {precision_score(y_test, y_pred_knn).round(4)*100}%')
print(f'Recall:   {recall_score(y_test, y_pred_knn).round(5)*100}%')
print(f'F1-Score: {f1_score(y_true=y_test, y_pred=y_pred_knn, average="weighted").round(4)*100}%')
# Out:
# Acurácia: 98.014%
# Precisão: 99.25%
# Recall:   98.371%
# F1-Score: 98.03%

# %%
fig, ax = plt.subplots(figsize=(10, 8))
plt.grid(False)
sns.set(font_scale=1.3)
plot_roc_curve(knn, X_test, y_test, ax=ax)
plt.title(label='Curva ROC - KNN', fontsize=14, pad=10)
plt.savefig('../Imagens/roc_knn')

# %%
nb = GaussianNB()
nb.fit(X_train, y_train)
y_pred_nb = nb.predict(X_test)

# %%
# Plotando a matriz de confusão.
fig, ax = plt.subplots(figsize=(8, 8))
plt.grid(False)
sns.set(font_scale=1.3)
plot_confusion_matrix(nb, X_test, y_test, cmap='YlGnBu', ax=ax)
ax.set_xlabel('Valor Predito')
ax.set_ylabel('Valor Real')
ax.set_xticklabels(['Not churn', 'Churn'])
ax.set_yticklabels(['Not churn', 'Churn'])
ax.set_title(label='Matriz de Confusão - Gaussian NB', fontsize=14, pad=10)
plt.savefig('../Imagens/confmatrix_nb')

# %%
print(f'Acurácia: {accuracy_score(y_test, y_pred_nb).round(5)*100}%')
print(f'Precisão: {precision_score(y_test, y_pred_nb).round(4)*100}%')
print(f'Recall:   {recall_score(y_test, y_pred_nb).round(6)*100}%')
print(f'F1-Score: {f1_score(y_true=y_test, y_pred=y_pred_nb, average="weighted").round(4)*100}%')
# Out:
# Acurácia: 90.069%
# Precisão: 91.34%
# Recall:   97.3707%
# F1-Score: 89.21%

# %%
fig, ax = plt.subplots(figsize=(10, 8))
plt.grid(False)
sns.set(font_scale=1.3)
plot_roc_curve(nb, X_test, y_test, ax=ax)
plt.title(label='Curva ROC - Gaussian NB', fontsize=14, pad=10)
plt.savefig('../Imagens/roc_nb')

# %%
dtree = DecisionTreeClassifier(max_depth=5)
dtree.fit(X_train, y_train)
y_pred_dtree = dtree.predict(X_test)

# %%
# Plotando a matriz de confusão.
fig, ax = plt.subplots(figsize=(8, 8))
plt.grid(False)
sns.set(font_scale=1.3)
plot_confusion_matrix(dtree, X_test, y_test, cmap='YlGnBu', ax=ax)
ax.set_xlabel('Valor Predito')
ax.set_ylabel('Valor Real')
ax.set_xticklabels(['Not churn', 'Churn'])
ax.set_yticklabels(['Not churn', 'Churn'])
ax.set_title(label='Matriz de Confusão - Decision Tree', fontsize=14, pad=10)
plt.savefig('../Imagens/confmatrix_dtree')

# %%
print(f'Acurácia: {accuracy_score(y_test, y_pred_dtree).round(6)*100}%')
print(f'Precisão: {precision_score(y_test, y_pred_dtree).round(4)*100}%')
print(f'Recall:   {recall_score(y_test, y_pred_dtree).round(4)*100}%')
print(f'F1-Score: {f1_score(y_true=y_test, y_pred=y_pred_dtree, average="weighted").round(3)*100}%')
# Out:
# Acurácia: 99.0189%
# Precisão: 98.98%
# Recall:   99.86%
# F1-Score: 99.0%

# %%
fig, ax = plt.subplots(figsize=(10, 8))
plt.grid(False)
sns.set(font_scale=1.3)
plot_roc_curve(dtree, X_test, y_test, ax=ax)
plt.title(label='Curva ROC - Decision Tree', fontsize=14, pad=10)
plt.savefig('../Imagens/roc_dtree')

# %%
modelXG = XGBClassifier()
modelXG.fit(X_train, y_train)
y_predXG = modelXG.predict(X_test)

# %%
# Plotando a matriz de confusão.
fig, ax = plt.subplots(figsize=(8, 8))
plt.grid(False)
sns.set(font_scale=1.3)
plot_confusion_matrix(modelXG, X_test, y_test, cmap='YlGnBu', ax=ax)
ax.set_xlabel('Valor Predito')
ax.set_ylabel('Valor Real')
ax.set_xticklabels(['Not churn', 'Churn'])
ax.set_yticklabels(['Not churn', 'Churn'])
ax.set_title(label='Matriz de Confusão - XG Boost', fontsize=14, pad=10)
plt.savefig('../Imagens/confmatrix_XGB')

# %%
print(f'Acurácia: {accuracy_score(y_test, y_predXG).round(4)*100}%')
print(f'Precisão: {precision_score(y_test, y_predXG).round(4)*100}%')
print(f'Recall:   {recall_score(y_test, y_predXG).round(5)*100}%')
print(f'F1-Score: {f1_score(y_true=y_test, y_pred=y_predXG, average="weighted").round(4)*100}%')
# Out:
# Acurácia: 99.9%
# Precisão: 99.89%
# Recall:   100.0%
# F1-Score: 99.9%

# %%
fig, ax = plt.subplots(figsize=(10, 8))
plt.grid(False)
sns.set(font_scale=1.3)
plot_roc_curve(modelXG, X_test, y_test, ax=ax)
plt.title(label='Curva ROC - XG Boost', fontsize=14, pad=10)
plt.savefig('../Imagens/roc_XGB')

# %% [markdown]
# ### Agora vamos comparar todas as curvas dos modelos para identificarmos os melhores resultados AUC.

# %%
fig, ax = plt.subplots(figsize=(12, 10))
plt.grid(False)
sns.set(font_scale=1.3)
classifiers = [lr, svm, knn, nb, dtree, modelXG]
ax = plt.gca()
for i in classifiers:
    plot_roc_curve(i, X_test, y_test, ax=ax)

ax.set_title(label='Comparativo das Curvas ROC de todos os Algoritmos', fontsize=14, pad=10)
plt.savefig('../Imagens/roc_todos')

# %% [markdown]
# ### Vamos montar um ensemble com os 3 melhores classificadores identificados acima.

# %%
# Instanciando os modelos individualmente.
clf_knn = KNeighborsClassifier(n_neighbors=3)
clf_dt = DecisionTreeClassifier(min_samples_leaf=3, min_samples_split=9, random_state=18)
clf_xgb = XGBClassifier(learning_rate=10, random_state=18)

# Definindo os estimadores selecionados.
estimators = [('knn', clf_knn), ('dtree', clf_dt), ('modelXG', clf_xgb)]

# Criando a avaliação dos classificadores e treinando o modelo.
clf_avg = VotingClassifier(estimators= estimators, voting='soft')
clf_avg.fit(X_train, y_train)

# Testando e avaliando o desempenho do modelo.
acc_avg = accuracy_score(y_test,  clf_avg.predict(X_test))
pre_avg = precision_score(y_test, clf_avg.predict(X_test))
recl_avg = recall_score(y_test, clf_avg.predict(X_test))
f1_avg = f1_score(y_true=y_test, y_pred=clf_avg.predict(X_test), average="weighted")

print('Acurácia: {:.4f}'.format(acc_avg))
print('Precisão: {:.4f}'.format(pre_avg))
print('Recall:   {:.4f}'.format(recl_avg))
print('F1-Score: {:.4f}'.format(f1_avg))
# Out:
# Acurácia: 0.9902
# Precisão: 0.9923
# Recall:   0.9960
# F1-Score: 0.9902

# %%
estimators = [('knn', clf_knn), ('dtree', clf_dt), ('modelXG', clf_xgb)]

clf_vote = VotingClassifier(estimators=estimators)
clf_vote.fit(X_train, y_train)

clf_avg = VotingClassifier(estimators=estimators, voting='soft')
clf_avg.fit(X_train, y_train)

acc_vote = accuracy_score(y_test, clf_vote.predict(X_test))
acc_avg = accuracy_score(y_test,  clf_avg.predict(X_test))
print('Voting: {:.4f}, Averaging: {:.4f}'.format(acc_vote, acc_avg))
# Out:
# Voting: 0.9904, Averaging: 0.9902

# %% [markdown]
# ### Vamos rodar o modelo com os dados desconhecidos para testar a eficácia.

# %%
# para igualar as bases de treino e teste, vamos separar uma amostra da 
# base desconhecida com o mesmo número de linhas da base de treino.
gg_test_2 = gg_test.sample(4180)
gg_test_2.drop(labels=68989, inplace=True) # havia uma linha com valores nulos e precisamos excluí-la.

# Listando os estimadores.
estimators = [('knn', clf_knn), ('dtree', clf_dt), ('modelXG', clf_xgb)]

# Construindo um voting classifier para avaliar os resultados.
clf_vote = VotingClassifier(estimators=estimators)
clf_vote.fit(X_train, y_train)

# Construindo um voting classifier da média para avaliar os resultados.
clf_avg = VotingClassifier(estimators=estimators, voting='hard')
clf_avg.fit(X_train, y_train)

# Avaliando o desempenho dos modelos.
acc_vote = accuracy_score(y_test, clf_vote.predict(gg_test_2))
acc_avg = accuracy_score(y_test,  clf_avg.predict(gg_test_2))
print('Voting: {:.2f}, Averaging: {:.2f}'.format(acc_vote, acc_avg))
# Out:
# Voting: 0.83, Averaging: 0.83

# %% [markdown]
# ### Vamos rodar o ensemble nos dados desconhecidos e extrair a lista de potenciais churns.

# %%
new_churn = clf_vote.predict(gg_test_2)

# %%
nch = pd.Series(new_churn)

# %%
nch
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 4174     True
# 4175     True
# 4176    False
# 4177     True
# 4178     True
# Length: 4179, dtype: bool

# %%
nch.value_counts()
# Out:
# True     4131
# False      48
# dtype: int64

# %%
y_test
# Out:
# 14365    False
# 10233     True
# 12026     True
# 7750      True
# 12567     True
#          ...
# 5378      True
# 9145      True
# 8325      True
# 9952      True
# 2730      True
# Name: churn, Length: 4179, dtype: bool

# %%
df_pred = pd.DataFrame()

# %%
df_pred['user_id'] = y_test.index

# %%
df_pred['nch'] = nch.tolist()

# %%
df_pred
# Out:
#       user_id    nch
# 0       14365   True
# 1       10233   True
# 2       12026   True
# 3        7750   True
# 4       12567   True
# ...       ...    ...
# 4174     5378   True
# 4175     9145   True
# 4176     8325  False
# 4177     9952   True
# 4178     2730   True
#
# [4179 rows x 2 columns]

# %%
df_not_churn = df_pred[['user_id']][df_pred['nch'] == 0]

# %%
df_churn = df_pred[['user_id']][df_pred['nch'] == 1]

# %%
df_churn.user_id.tolist()
# Out:
# [14365,
#  10233,
#  12026,
#  7750,
#  12567,
#  16061,
#  9265,
#  14584,
#  8414,
#  9659,
#  13826,
#  3383,
#  9065,
#  10922,
#  3789,
#  3086,
#  3680,
#  10764,
#  12016,
#  1433,
#  14861,
#  2790,
#  13244,
#  1864,
#  12842,
#  5007,
#  10029,
#  3049,
#  13887,
#  14765,
#  9002,
#  15824,
#  15954,
#  14730,
#  8359,
#  13315,
#  9508,
#  10135,
#  5034,
#  5900,
#  3229,
#  75,
#  9216,
#  14274,
#  15226,
#  8456,
#  685,
#  5370,
#  7466,
#  9899,
#  274,
#  4891,
#  10772,
#  11806,
#  16198,
#  3175,
#  4897,
#  9307,
#  1722,
#  5965,
#  9917,
#  1953,
#  11757,
#  9776,
#  8300,
#  12357,
#  15732,
#  4439,
#  3427,
#  7912,
#  12780,
#  13271,
#  11238,
#  5682,
#  7870,
#  15027,
#  15637,
#  13797,
#  2203,
#  5775,
#  11690,
#  13808,
#  12022,
#  13338,
#  6151,
#  1992,
#  4673,
#  5309,
#  13405,
#  16235,
#  16346,
#  8136,
#  3185,
#  5123,
#  11638,
#  6505,
#  3358,
#  6330,
#  6786,
#  8092,
#  13793,
#  5317,
#  9553,
#  12647,
#  11470,
#  5699,
#  6447,
#  15940,
#  9387,
#  2805,
#  810,
#  15870,
#  11239,
#  7767,
#  1995,
#  9984,
#  14423,
#  5999,
#  6332,
#  15831,
#  13441,
#  6368,
#  13988,
#  15583,
#  4154,
#  6738,
#  14652,
#  16145,
#  9426,
#  8479,
#  5410,
#  7605,
#  13586,
#  10912,
#  16135,
#  1811,
#  9438,
#  14831,
#  14119,
#  15171,
#  1021,
#  7753,
#  9280,
#  10354,
#  15963,
#  13933,
#  9662,
#  10661,
#  8951,
#  10280,
#  9257,
#  12641,
#  3080,
#  16236,
#  8836,
#  12814,
#  2394,
#  15087,
#  3655,
#  9955,
#  9450,
#  15202,
#  6138,
#  2986,
#  2847,
#  12071,
#  9876,
#  11677,
#  13847,
#  14939,
#  11148,
#  94,
#  15051,
#  7451,
#  830,
#  12754,
#  1937,
#  6868,
#  10189,
#  3767,
#  11019,
#  8843,
#  14037,
#  8010,
#  7396,
#  6254,
#  6983,
#  658,
#  11670,
#  4793,
#  1697,
#  1056,
#  7554,
#  16245,
#  15459,
#  13121,
#  3726,
#  16323,
#  2534,
#  8417,
#  4131,
#  16343,
#  9231,
#  4605,
#  10885,
#  7640,
#  5163,
#  3133,
#  9705,
#  9552,
#  16587,
#  4548,
#  11748,
#  4771,
#  15313,
#  2952,
#  16012,
#  16128,
#  15080,
#  15435,
#  3686,
#  16689,
#  3860,
#  16401,
#  5704,
#  2920,
#  5043,
#  7875,
#  3663,
#  8358,
#  4276,
#  15515,
#  1162,
#  10353,
#  2443,
#  14192,
#  12716,
#  8377,
#  15948,
#  16043,
#  7287,
#  6353,
#  747,
#  15398,
#  12442,
#  6075,
#  731,
#  1742,
#  5119,
#  13076,
#  11264,
#  2827,
#  5929,
#  1729,
#  7555,
#  12492,
#  6010,
#  4246,
#  12062,
#  9133,
#  8990,
#  1780,
#  7727,
#  1617,
#  6523,
#  11572,
#  8284,
#  1051,
#  8360,
#  6476,
#  10803,
#  12953,
#  10813,
#  3467,
#  3233,
#  4264,
#  14743,
#  5252,
#  10650,
#  1066,
#  11554,
#  9947,
#  1534,
#  15971,
#  520,
#  12511,
#  3606,
#  8961,
#  6541,
#  4165,
#  7474,
#  3587,
#  15008,
#  2338,
#  15978,
#  10021,
#  15624,
#  6290,
#  14848,
#  6729,
#  11288,
#  2773,
#  7378,
#  2362,
#  3968,
#  11080,
#  5909,
#  7784,
#  12949,
#  10685,
#  30,
#  5321,
#  1927,
#  5601,
#  3574,
#  7846,
#  1153,
#  14085,
#  5825,
#  5831,
#  2891,
#  12325,
#  10174,
#  7421,
#  6394,
#  4612,
#  8574,
#  10578,
#  3347,
#  4175,
#  2100,
#  10934,
#  3300,
#  1658,
#  5740,
#  3746,
#  15107,
#  3751,
#  9652,
#  14618,
#  4680,
#  15693,
#  11551,
#  3204,
#  13918,
#  3666,
#  4414,
#  1916,
#  3176,
#  4578,
#  8342,
#  4692,
#  13532,
#  1713,
#  12999,
#  14724,
#  15791,
#  6901,
#  9201,
#  2085,
#  11350,
#  8516,
#  16459,
#  11123,
#  8798,
#  3801,
#  12990,
#  14084,
#  3317,
#  2379,
#  9424,
#  3870,
#  15084,
#  10608,
#  6754,
#  14448,
#  8168,
#  9429,
#  13330,
#  13619,
#  12181,
#  2934,
#  7564,
#  12498,
#  3212,
#  14449,
#  6556,
#  9128,
#  16707,
#  13411,
#  9046,
#  9239,
#  15757,
#  13516,
#  5282,
#  4772,
#  12625,
#  2230,
#  1178,
#  7878,
#  8014,
#  12889,
#  3156,
#  1537,
#  12966,
#  9644,
#  13162,
#  13102,
#  2044,
#  423,
#  5341,
#  10001,
#  7213,
#  13810,
#  13357,
#  4355,
#  326,
#  6379,
#  3600,
#  12697,
#  14419,
#  7526,
#  8247,
#  3753,
#  1333,
#  6569,
#  14749,
#  6174,
#  8259,
#  14114,
#  5461,
#  9691,
#  2323,
#  13777,
#  8373,
#  12400,
#  12621,
#  11947,
#  7683,
#  86,
#  13204,
#  9038,
#  1076,
#  15572,
#  11191,
#  916,
#  13962,
#  12701,
#  3335,
#  1228,
#  3917,
#  11126,
#  8047,
#  12971,
#  13377,
#  15117,
#  6098,
#  10318,
#  15575,
#  14811,
#  15037,
#  7344,
#  2549,
#  16694,
#  9241,
#  6349,
#  12859,
#  16379,
#  3350,
#  9818,
#  12737,
#  15522,
#  8245,
#  16015,
#  11890,
#  15747,
#  14029,
#  15842,
#  7469,
#  16190,
#  7743,
#  8995,
#  13234,
#  7665,
#  2579,
#  1332,
#  5148,
#  14086,
#  8543,
#  8635,
#  4040,
#  6399,
#  1912,
#  1624,
#  1139,
#  14071,
#  2515,
#  10878,
#  15344,
#  11456,
#  3540,
#  8205,
#  4653,
#  15053,
#  5065,
#  3052,
#  58,
#  4089,
#  4631,
#  13221,
#  12164,
#  1335,
#  10192,
#  6530,
#  3247,
#  12825,
#  12820,
#  13812,
#  3892,
#  3227,
#  4118,
#  2461,
#  6001,
#  12548,
#  783,
#  6654,
#  12892,
#  4974,
#  15057,
#  7200,
#  8209,
#  10030,
#  14389,
#  9615,
#  12435,
#  5257,
#  11309,
#  6264,
#  13928,
#  3207,
#  2221,
#  13241,
#  8197,
#  15262,
#  1508,
#  7740,
#  15360,
#  16549,
#  6112,
#  13423,
#  10852,
#  6244,
#  10242,
#  13633,
#  10964,
#  3765,
#  10415,
#  1313,
#  15240,
#  15224,
#  12848,
#  12775,
#  2555,
#  4269,
#  14678,
#  14327,
#  7685,
#  2030,
#  14718,
#  8255,
#  5936,
#  2291,
#  16488,
#  12280,
#  6341,
#  8483,
#  6858,
#  1311,
#  14702,
#  3436,
#  11541,
#  2388,
#  13823,
#  11447,
#  5357,
#  14864,
#  12845,
#  7071,
#  14543,
#  15999,
#  7546,
#  10238,
#  14466,
#  11563,
#  16428,
#  8244,
#  4921,
#  721,
#  12060,
#  7418,
#  8215,
#  96,
#  2919,
#  12909,
#  13165,
#  12587,
#  1603,
#  1437,
#  13027,
#  11134,
#  2272,
#  15305,
#  912,
#  6547,
#  1080,
#  5631,
#  9134,
#  2519,
#  15591,
#  1846,
#  14602,
#  1986,
#  1614,
#  8643,
#  6780,
#  1305,
#  14780,
#  8485,
#  1440,
#  14066,
#  9207,
#  16552,
#  10826,
#  13591,
#  12710,
#  5403,
#  10887,
#  2247,
#  15897,
#  1509,
#  5099,
#  14439,
#  1651,
#  14006,
#  993,
#  10409,
#  7497,
#  9016,
#  4012,
#  16087,
#  5172,
#  1355,
#  11825,
#  1122,
#  6458,
#  2941,
#  5791,
#  4606,
#  232,
#  10388,
#  8408,
#  814,
#  9567,
#  3906,
#  8941,
#  14917,
#  8289,
#  8853,
#  5917,
#  1371,
#  16450,
#  15704,
#  11045,
#  7132,
#  6236,
#  10438,
#  3748,
#  4349,
#  3880,
#  6669,
#  1700,
#  11768,
#  7959,
#  8053,
#  11854,
#  9793,
#  3258,
#  16508,
#  895,
#  12036,
#  943,
#  3621,
#  11351,
#  2648,
#  1190,
#  10276,
#  1572,
#  9551,
#  603,
#  11231,
#  8628,
#  1444,
#  8146,
#  11843,
#  7489,
#  14263,
#  8756,
#  15700,
#  861,
#  5989,
#  1450,
#  3384,
#  133,
#  14572,
#  13001,
#  6849,
#  8813,
#  12927,
#  3812,
#  5603,
#  2649,
#  12000,
#  5966,
#  4462,
#  1382,
#  16030,
#  15964,
#  10672,
#  14934,
#  14583,
#  3034,
#  16182,
#  13509,
#  6302,
#  6255,
#  6311,
#  8648,
#  960,
#  10512,
#  15114,
#  8058,
#  5742,
#  9897,
#  1516,
#  3420,
#  10261,
#  16003,
#  11408,
#  6024,
#  10739,
#  6962,
#  9998,
#  5792,
#  16396,
#  3586,
#  2490,
#  10290,
#  11534,
#  3458,
#  927,
#  14277,
#  8677,
#  9283,
#  1878,
#  6965,
#  16484,
#  15029,
#  4472,
#  7148,
#  7587,
#  7237,
#  6023,
#  16629,
#  10626,
#  15653,
#  226,
#  20,
#  14357,
#  13252,
#  2429,
#  2457,
#  10305,
#  1975,
#  6799,
#  284,
#  14144,
#  3330,
#  11029,
#  881,
#  13779,
#  6233,
#  6853,
#  2532,
#  1824,
#  2908,
#  14692,
#  5018,
#  7801,
#  5053,
#  1101,
#  16032,
#  8820,
#  1364,
#  3694,
#  10863,
#  7850,
#  11348,
#  9911,
#  8934,
#  11223,
#  11828,
#  4507,
#  2754,
#  14214,
#  10431,
#  14693,
#  2796,
#  6313,
#  269,
#  5300,
#  5450,
#  8218,
#  11149,
#  5747,
#  4853,
#  13563,
#  12202,
#  14904,
#  7570,
#  15220,
#  14590,
#  8513,
#  3039,
#  10114,
#  13147,
#  994,
#  10800,
#  3329,
#  11390,
#  11490,
#  5178,
#  3768,
#  10673,
#  4250,
#  3567,
#  6504,
#  7811,
#  7359,
#  60,
#  16365,
#  11663,
#  3594,
#  16383,
#  9417,
#  7362,
#  3048,
#  12162,
#  8012,
#  6009,
#  6943,
#  1160,
#  4280,
#  129,
#  4568,
#  11910,
#  842,
#  3611,
#  4466,
#  12659,
#  7965,
#  2107,
#  12698,
#  11749,
#  6877,
#  318,
#  9012,
#  11336,
#  12464,
#  12729,
#  1464,
#  13819,
#  13477,
#  13327,
#  11803,
#  341,
#  10617,
#  16310,
#  10273,
#  11591,
#  12665,
#  11022,
#  3092,
#  6266,
#  14360,
#  14553,
#  16156,
#  4062,
#  4333,
#  6083,
#  209,
#  12768,
#  11383,
#  5830,
#  15031,
#  3843,
#  6508,
#  8959,
#  1251,
#  15654,
#  14008,
#  5314,
#  8221,
#  7947,
#  5404,
#  7613,
#  3986,
#  4721,
#  6782,
#  356,
#  5427,
#  11101,
#  16078,
#  2697,
#  1171,
#  14120,
#  2224,
#  9113,
#  9641,
#  4769,
#  13020,
#  13666,
#  15789,
#  13214,
#  3588,
#  3069,
#  8060,
#  13889,
#  15238,
#  11065,
#  14116,
#  5894,
#  13946,
#  2428,
#  7183,
#  7326,
#  11070,
#  15106,
#  608,
#  97,
#  13993,
#  7522,
#  2295,
#  14487,
#  9297,
#  7306,
#  2012,
#  14677,
#  15243,
#  10534,
#  2383,
#  7650,
#  11060,
#  5072,
#  12184,
#  10483,
#  5697,
#  11862,
#  8799,
#  7009,
#  9112,
#  16567,
#  14154,
#  5111,
#  4464,
#  3729,
#  8281,
#  3936,
#  3987,
#  14256,
#  3742,
#  5284,
#  14950,
#  2342,
#  13003,
#  12590,
#  976,
#  4532,
#  956,
#  2761,
#  15819,
#  2268,
#  11665,
#  622,
#  6582,
#  12925,
#  690,
#  624,
#  4654,
#  14976,
#  1193,
#  ...]

# %% [markdown]
# # Conclusão:
# ### Realmente, o número de churn e potenciais churns é muito alto, indicando que serão necessárias diversas melhorias no app para que os usuários queiram ficar por mais tempo.
# ### Para isso, nós vamos trabalhar com a construção de algoritmos de recomendação de jogos, para melhorar a biblioteca de jogos dos usuários; e de recomendação de conexões, para sugerir conexões mais relevantes para os usuários.
